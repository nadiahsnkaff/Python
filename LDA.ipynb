# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiahsnkaff/Python/blob/main/LDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to handle datasets
import pandas as pd
import numpy as np

# to divide train and test set
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import StandardScaler, FunctionTransformer

# create pipeline
from sklearn.pipeline import Pipeline

# LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load dataset
df=pd.read_csv('/content/drive/MyDrive/PythonProject/Breast_GSE70947.csv')
df.head()
# Out:
#    type  NM_144987  NM_013290  ENST00000322831  NM_001625  \
# 0     0   8.693318   7.718016         6.044438  10.747077
# 1     0   9.375980   7.072232         6.976741  10.429671
# 2     0   8.943442   7.964573         6.269055  10.825025
# 3     0   9.020798   7.824639         6.165165  11.646788
# 4     0   8.806154   7.555348         6.230969  11.635247
#
#    lincRNA:chr7:226042-232442_R  NM_032391  ENST00000238571  XR_108906  \
# 0                      9.133777   4.735581         5.634732   4.670231
# 1                      9.526500   5.221089         5.425187   4.860931
# 2                      9.396855   5.258506         5.824921   4.964604
# 3                      8.776462   4.648655         6.676692   4.770186
# 4                      8.911383   4.518054         6.520691   4.540453
#
#    NM_005937  ...  NM_207327  NM_001004477  NM_020700  NM_005895  NM_000679  \
# 0  11.152649  ...  10.453202      4.376090   5.597596  11.860087  11.321528
# 1  10.839289  ...  10.066372      4.383785   5.404546  11.636828   8.283747
# 2  10.884157  ...  10.380676      4.428892   5.356374  12.031338   9.420630
# 3  10.646459  ...  10.509871      4.381542   5.757179  11.944607  10.311339
# 4  10.939783  ...  10.552841      4.386116   6.851058  11.976510  10.904219
#
#    NR_003529  NR_036446  NM_001001957  lincRNA:chr7:29652000-29661000_R  \
# 0   4.486530   5.489959      5.810069                          4.834056
# 1   4.770318   5.345571      4.457930                          4.441395
# 2   4.394069   5.851030      4.508072                          4.568262
# 3   4.451118   6.117379      4.505663                          4.413361
# 4   4.432566   6.286439      4.540453                          4.412933
#
#    ENST00000494108
# 0         4.383929
# 1         4.411587
# 2         4.316081
# 3         4.537626
# 4         4.452250
#
# [5 rows x 16383 columns]

# %%
df.shape
# Out:
# (289, 16383)

# %%
target_name = 'type'

#separate object for target feature
y = df[target_name]

#separate object for input feature
X = df.drop(target_name, axis=1)

# %%
#split the dataset into training set and test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    # we are setting the seed here
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((202, 16382), (87, 16382))

# %%
X_test.shape, y_test.shape
# Out:
# ((87, 16382), (87,))

# %%
# feature scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### LDA

# %%
scaler_1 = StandardScaler()
X_scld = scaler_1.fit_transform(X)

# %%
lda1=LDA(store_covariance=True)

train_lda_fitting = lda1.fit(X_scld, y)

# %%
n_pcs= lda1.covariance_.shape[0]

# get the index of the most important feature on EACH component i.e. largest absolute value
# using LIST COMPREHENSION HERE
most_important = [np.abs(lda1.covariance_[i]).argmax() for i in range(n_pcs)]

initial_feature_names = X.columns

# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

# using LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i+1): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df_LDA = pd.DataFrame(sorted(dic.items()))
df_LDA.columns=['Components','Important Feature']

# %%
df_LDA.shape
# Out:
# (16382, 2)

# %%
df_LDA
# Out:
#       Components                   Important Feature
# 0            PC1                           NM_144987
# 1           PC10                           NM_152493
# 2          PC100  lincRNA:chr9:132096359-132104173_R
# 3         PC1000                     ENST00000319813
# 4        PC10000                           NM_178568
# ...          ...                                 ...
# 16377     PC9995                        NM_001012409
# 16378     PC9996                           NM_001277
# 16379     PC9997  lincRNA:chr6:147227807-147238032_R
# 16380     PC9998                           NM_000517
# 16381     PC9999                           NM_000830
#
# [16382 rows x 2 columns]

# %%
selected_features_by_LDA = df_LDA['Important Feature'].values

# %%
len(selected_features_by_LDA)
# Out:
# 16382

# %% [markdown]
# # Final Results

# %%
features=sorted(df.drop('type',axis=1).columns)

# %%
df.head()
# Out:
#    type  NM_144987  NM_013290  ENST00000322831  NM_001625  \
# 0     0   8.693318   7.718016         6.044438  10.747077
# 1     0   9.375980   7.072232         6.976741  10.429671
# 2     0   8.943442   7.964573         6.269055  10.825025
# 3     0   9.020798   7.824639         6.165165  11.646788
# 4     0   8.806154   7.555348         6.230969  11.635247
#
#    lincRNA:chr7:226042-232442_R  NM_032391  ENST00000238571  XR_108906  \
# 0                      9.133777   4.735581         5.634732   4.670231
# 1                      9.526500   5.221089         5.425187   4.860931
# 2                      9.396855   5.258506         5.824921   4.964604
# 3                      8.776462   4.648655         6.676692   4.770186
# 4                      8.911383   4.518054         6.520691   4.540453
#
#    NM_005937  ...  NM_207327  NM_001004477  NM_020700  NM_005895  NM_000679  \
# 0  11.152649  ...  10.453202      4.376090   5.597596  11.860087  11.321528
# 1  10.839289  ...  10.066372      4.383785   5.404546  11.636828   8.283747
# 2  10.884157  ...  10.380676      4.428892   5.356374  12.031338   9.420630
# 3  10.646459  ...  10.509871      4.381542   5.757179  11.944607  10.311339
# 4  10.939783  ...  10.552841      4.386116   6.851058  11.976510  10.904219
#
#    NR_003529  NR_036446  NM_001001957  lincRNA:chr7:29652000-29661000_R  \
# 0   4.486530   5.489959      5.810069                          4.834056
# 1   4.770318   5.345571      4.457930                          4.441395
# 2   4.394069   5.851030      4.508072                          4.568262
# 3   4.451118   6.117379      4.505663                          4.413361
# 4   4.432566   6.286439      4.540453                          4.412933
#
#    ENST00000494108
# 0         4.383929
# 1         4.411587
# 2         4.316081
# 3         4.537626
# 4         4.452250
#
# [5 rows x 16383 columns]

# %%
# Putting all selections together
def get_true_false(selected_features, features):
    selected_t_f = []
    for feature in features:
        if feature in selected_features:
            selected_t_f.append(True)
        else:
            selected_t_f.append(False)
    return selected_t_f

# %%
features = sorted(df.drop('type', axis=1).columns)
df_selections = pd.DataFrame({'Feature': features,
                              'LDA': get_true_false(selected_features_by_LDA, features)})
df_selections['Total'] = np.sum(df_selections, axis=1)
df_selections = df_selections.sort_values(['Total', 'Feature'], ascending=False)
df_selections.index = range(1, len(df_selections) + 1)
df_selections
# Out:
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:84: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return reduction(axis=axis, out=out, **passkwargs)
#                                 Feature    LDA  Total
# 1      lincRNA:chrX:98168819-98180169_R   True      1
# 2      lincRNA:chrX:98168819-98180169_F   True      1
# 3      lincRNA:chrX:97828994-98135519_R   True      1
# 4      lincRNA:chrX:97828872-98120013_F   True      1
# 5      lincRNA:chrX:93821069-94033669_R   True      1
# ...                                 ...    ...    ...
# 16378                         NM_003524  False      0
# 16379                         NM_002487  False      0
# 16380                         NM_000088  False      0
# 16381                      A_24_P256063  False      0
# 16382                      A_24_P230057  False      0
#
# [16382 rows x 3 columns]

# %%
df_selections[0:10]
# Out:
#                              Feature   LDA  Total
# 1   lincRNA:chrX:98168819-98180169_R  True      1
# 2   lincRNA:chrX:98168819-98180169_F  True      1
# 3   lincRNA:chrX:97828994-98135519_R  True      1
# 4   lincRNA:chrX:97828872-98120013_F  True      1
# 5   lincRNA:chrX:93821069-94033669_R  True      1
# 6   lincRNA:chrX:93547644-94240194_F  True      1
# 7     lincRNA:chrX:7922607-7924183_F  True      1
# 8   lincRNA:chrX:73794800-73800175_F  True      1
# 9   lincRNA:chrX:73484537-73485162_R  True      1
# 10  lincRNA:chrX:73464315-73465078_R  True      1

# %%
final_selected = list(df_selections[df_selections['Total'] == 1]['Feature'])

# %%
final_selected
# Out:
# ['lincRNA:chrX:98168819-98180169_R',
#  'lincRNA:chrX:98168819-98180169_F',
#  'lincRNA:chrX:97828994-98135519_R',
#  'lincRNA:chrX:97828872-98120013_F',
#  'lincRNA:chrX:93821069-94033669_R',
#  'lincRNA:chrX:93547644-94240194_F',
#  'lincRNA:chrX:7922607-7924183_F',
#  'lincRNA:chrX:73794800-73800175_F',
#  'lincRNA:chrX:73484537-73485162_R',
#  'lincRNA:chrX:73464315-73465078_R',
#  'lincRNA:chrX:73425071-73428011_R',
#  'lincRNA:chrX:73423619-73512308_F',
#  'lincRNA:chrX:73419700-73513050_F',
#  'lincRNA:chrX:73164675-73232924_R',
#  'lincRNA:chrX:73164675-73232875_R',
#  'lincRNA:chrX:73164437-73224386_R',
#  'lincRNA:chrX:73061217-73072588_F',
#  'lincRNA:chrX:73050901-73051109_F',
#  'lincRNA:chrX:71132475-71339425_F',
#  'lincRNA:chrX:70247475-70252650_R',
#  'lincRNA:chrX:70247475-70252650_F',
#  'lincRNA:chrX:68406650-68432200_R',
#  'lincRNA:chrX:68399399-68429767_F',
#  'lincRNA:chrX:68110750-68116075_R',
#  'lincRNA:chrX:65009725-65085200_R',
#  'lincRNA:chrX:65009725-65085200_F',
#  'lincRNA:chrX:64209375-64701425_F',
#  'lincRNA:chrX:62643325-62657450_F',
#  'lincRNA:chrX:62511850-62529650_F',
#  'lincRNA:chrX:57927950-57934100_F',
#  'lincRNA:chrX:57169300-57284475_R',
#  'lincRNA:chrX:56807400-56832200_F',
#  'lincRNA:chrX:56771900-56794000_R',
#  'lincRNA:chrX:55936225-56241400_R',
#  'lincRNA:chrX:55936225-56241400_F',
#  'lincRNA:chrX:55934555-56041395_F',
#  'lincRNA:chr9:129170054-129170184_R',
#  'lincRNA:chr9:129170054-129170184_F',
#  'lincRNA:chr9:12758800-12759752_R',
#  'lincRNA:chr9:126100254-126117679_R',
#  'lincRNA:chr9:125875154-125883803_R',
#  'lincRNA:chr9:123702679-123713129_F',
#  'lincRNA:chr9:123606154-123611279_F',
#  'lincRNA:chr9:118588179-118601004_R',
#  'lincRNA:chr9:118241254-118292704_F',
#  'lincRNA:chr9:114967654-114975997_F',
#  'lincRNA:chr9:114967654-114975954_R',
#  'lincRNA:chr9:114795825-114797203_R',
#  'lincRNA:chr9:114790179-114798242_R',
#  'lincRNA:chr9:114435054-114447929_F',
#  'lincRNA:chr9:111293604-111458604_R',
#  'lincRNA:chr9:110795954-110822204_R',
#  'lincRNA:chr9:109023754-109044179_R',
#  'lincRNA:chr9:109023754-109044179_F',
#  'lincRNA:chr9:101999104-102004154_R',
#  'lincRNA:chr8:96743021-96861105_R',
#  'lincRNA:chr8:96692149-96730174_F',
#  'lincRNA:chr8:96219368-96228602_R',
#  'lincRNA:chr8:96120599-96125999_R',
#  'lincRNA:chr8:96083967-96100152_R',
#  'lincRNA:chr8:96083774-96119899_R',
#  'lincRNA:chr8:95989649-96006474_R',
#  'lincRNA:chr8:95989649-96006474_F',
#  'lincRNA:chr8:95986835-95996412_R',
#  'lincRNA:chr8:95917724-95933974_R',
#  'lincRNA:chr8:94968549-94974474_F',
#  'lincRNA:chr8:93384199-93389724_R',
#  'lincRNA:chr8:92105274-92110499_R',
#  'lincRNA:chr8:92105274-92110499_F',
#  'lincRNA:chr8:91681974-91687749_R',
#  'lincRNA:chr8:91681974-91687749_F',
#  'lincRNA:chr8:91113099-91397399_R',
#  'lincRNA:chr8:90733146-90737134_F',
#  'lincRNA:chr8:90618650-90619014_R',
#  'lincRNA:chr8:90615284-90628709_R',
#  'lincRNA:chr8:8933665-8942715_R',
#  'lincRNA:chr8:8777340-8841140_F',
#  'lincRNA:chr8:87026584-87038559_F',
#  'lincRNA:chr8:8480290-8488065_F',
#  'lincRNA:chr8:79635995-79642470_F',
#  'lincRNA:chr8:76121095-76189420_R',
#  'lincRNA:chr8:74964574-75012085_F',
#  'lincRNA:chr8:72443025-72504238_R',
#  'lincRNA:chr8:67834252-67838633_R',
#  'lincRNA:chr8:67830421-67837540_R',
#  'lincRNA:chr8:67304071-67319246_R',
#  'lincRNA:chr8:66501846-66512866_F',
#  'lincRNA:chr8:66501846-66512821_R',
#  'lincRNA:chr8:6516692-6533242_R',
#  'lincRNA:chr8:60062921-60832721_F',
#  'lincRNA:chr8:599650-609000_R',
#  'lincRNA:chr8:590407-594400_R',
#  'lincRNA:chr8:590406-605477_F',
#  'lincRNA:chr8:587535-591207_R',
#  'lincRNA:chr8:582466-583006_R',
#  'lincRNA:chr8:58142119-58150379_R',
#  'lincRNA:chr8:58115146-58143017_R',
#  'lincRNA:chr8:58115146-58143017_F',
#  'lincRNA:chr8:58106178-58152853_R',
#  'lincRNA:chr8:561925-598750_F',
#  'lincRNA:chr8:55350297-55366022_F',
#  'lincRNA:chr6:86387046-86387917_F',
#  'lincRNA:chr6:86386813-86387908_F',
#  'lincRNA:chr6:86386801-86387965_F',
#  'lincRNA:chr6:86386083-86388435_R',
#  'lincRNA:chr6:86381806-86396056_F',
#  'lincRNA:chr6:85326131-85332581_F',
#  'lincRNA:chr6:85200406-85205831_F',
#  'lincRNA:chr6:84676486-84677143_F',
#  'lincRNA:chr6:83087506-83099056_F',
#  'lincRNA:chr6:81150446-81150889_F',
#  'lincRNA:chr6:81144331-81171231_R',
#  'lincRNA:chr6:80256857-80257505_F',
#  'lincRNA:chr6:80248431-80271605_F',
#  'lincRNA:chr6:80248431-80271556_R',
#  'lincRNA:chr6:79555431-79563106_F',
#  'lincRNA:chr6:78190846-78213705_R',
#  'lincRNA:chr6:73130154-73135679_R',
#  'lincRNA:chr6:73130154-73135679_F',
#  'lincRNA:chr6:72071404-72129621_R',
#  'lincRNA:chr6:72071404-72129621_F',
#  'lincRNA:chr6:72033379-72059179_R',
#  'lincRNA:chr6:72017387-72024304_F',
#  'lincRNA:chr6:6794382-6801404_R',
#  'lincRNA:chr6:6711294-6759575_R',
#  'lincRNA:chr6:6683526-6811251_R',
#  'lincRNA:chr6:6683526-6701601_R',
#  'lincRNA:chr6:57535316-57542016_R',
#  'lincRNA:chr6:57535316-57542016_F',
#  'lincRNA:chr6:56922016-56934541_R',
#  'lincRNA:chr6:56809416-56818616_R',
#  'lincRNA:chr6:56809416-56818616_F',
#  'lincRNA:chr6:56727979-56729136_R',
#  'lincRNA:chr6:53596641-53636866_R',
#  'lincRNA:chr6:53596641-53636866_F',
#  'lincRNA:chr6:53121666-53131541_F',
#  'lincRNA:chr6:5047814-5048418_F',
#  'lincRNA:chr6:45603101-45633284_F',
#  'lincRNA:chr6:4489031-4490044_F',
#  'lincRNA:chr6:44059763-44060019_F',
#  'lincRNA:chr6:44052354-44052747_R',
#  'lincRNA:chr6:44052354-44052747_F',
#  'lincRNA:chr6:44006347-44063172_F',
#  'lincRNA:chr6:44006347-44033347_R',
#  'lincRNA:chr6:43946747-43965218_F',
#  'lincRNA:chr6:43817785-43819573_F',
#  'lincRNA:chr6:43815372-43929922_R',
#  'lincRNA:chr6:43815372-43856747_R',
#  'lincRNA:chr6:43815372-43856747_F',
#  'lincRNA:chr6:43691472-43716272_F',
#  'lincRNA:chr6:42758417-42759055_F',
#  'lincRNA:chr6:42725472-42759772_F',
#  'lincRNA:chr6:41411797-41426472_R',
#  'lincRNA:chr6:41367472-41469722_F',
#  'lincRNA:chr6:41105597-41111597_R',
#  'lincRNA:chr6:41089139-41090988_R',
#  'lincRNA:chr6:41014072-41020197_R',
#  'lincRNA:chr6:40312082-40313891_F',
#  'lincRNA:chr6:40304947-40323847_R',
#  'lincRNA:chr6:40304947-40323847_F',
#  'lincRNA:chr6:39949522-39974972_R',
#  'lincRNA:chr6:39949522-39974972_F',
#  'lincRNA:chr6:3981526-3994101_R',
#  'lincRNA:chr6:3909888-3911910_R',
#  'lincRNA:chr6:3908054-3908574_R',
#  'lincRNA:chr6:167650999-167651886_F',
#  'lincRNA:chr6:167455835-167461547_R',
#  'lincRNA:chr6:167382710-167411729_R',
#  'lincRNA:chr6:167382710-167411729_F',
#  'lincRNA:chr6:167312435-167335360_R',
#  'lincRNA:chr6:167312435-167323185_R',
#  'lincRNA:chr6:166246785-166257910_R',
#  'lincRNA:chr6:166246785-166257910_F',
#  'lincRNA:chr6:160142860-160147960_R',
#  'lincRNA:chr6:158658627-158666616_F',
#  'lincRNA:chr6:155342808-155348158_F',
#  'lincRNA:chr6:155240958-155286533_R',
#  'lincRNA:chr6:155240958-155286533_F',
#  'lincRNA:chr6:155216183-155236483_R',
#  'lincRNA:chr6:155203224-155205268_F',
#  'lincRNA:chr6:155162159-155163338_F',
#  'lincRNA:chr6:154718233-154725342_R',
#  'lincRNA:chr6:154718233-154725333_F',
#  'lincRNA:chr6:152019457-152074007_F',
#  'lincRNA:chr6:151713007-151720482_F',
#  'lincRNA:chr6:147227807-147238032_R',
#  'lincRNA:chr6:147189982-147499757_R',
#  'lincRNA:chr6:147182939-147440585_F',
#  'lincRNA:chr6:14706771-14748171_F',
#  'lincRNA:chr6:14649596-14677521_R',
#  'lincRNA:chr6:144408057-144415732_F',
#  'lincRNA:chr6:14283301-14285685_R',
#  'lincRNA:chr6:14230071-14628896_F',
#  'lincRNA:chr6:141164532-141223557_F',
#  'lincRNA:chr6:139809107-140148457_F',
#  'lincRNA:chr6:139015455-139017888_F',
#  'lincRNA:chr6:138961057-139020207_F',
#  'lincRNA:chr6:138901082-138950307_R',
#  'lincRNA:chr6:138145796-138182040_R',
#  'lincRNA:chr6:134750285-134841723_F',
#  'lincRNA:chr6:132278082-132290382_F',
#  'lincRNA:chr6:132228532-132259157_F',
#  'lincRNA:chr6:131623907-131673757_R',
#  'lincRNA:chr6:129840957-129879607_F',
#  'lincRNA:chr6:127683868-127683995_R',
#  'lincRNA:chr6:126693482-126703082_F',
#  'lincRNA:chr6:126448907-126453957_F',
#  'lincRNA:chr6:126379957-126409982_F',
#  'lincRNA:chr6:125237916-125256255_F',
#  'lincRNA:chr6:12005039-12011214_F',
#  'lincRNA:chr6:119676776-120056276_F',
#  'lincRNA:chr6:116759632-116767182_R',
#  'lincRNA:chr6:116759632-116767182_F',
#  'lincRNA:chr6:114722782-114743483_R',
#  'lincRNA:chr6:113948595-113971480_R',
#  'lincRNA:chr6:113694157-113705157_R',
#  'lincRNA:chr6:113672332-113690598_F',
#  'lincRNA:chr6:111839957-111874407_F',
#  'lincRNA:chr6:111815840-111817068_R',
#  'lincRNA:chr6:111806107-111823857_R',
#  'lincRNA:chr6:111599134-111599947_R',
#  'lincRNA:chr6:111597396-111599952_F',
#  'lincRNA:chr6:111594332-111604057_R',
#  'lincRNA:chr6:109006232-109021407_R',
#  'lincRNA:chr6:108346507-108355057_R',
#  'lincRNA:chr6:107194959-107220168_F',
#  'lincRNA:chr6:107182919-107187643_F',
#  'lincRNA:chr6:106935857-106946432_F',
#  'lincRNA:chr6:106858857-106926507_R',
#  'lincRNA:chr6:106810232-106852232_F',
#  'lincRNA:chr6:106210957-106258507_F',
#  'lincRNA:chr6:105150782-105175032_R',
#  'lincRNA:chr6:100751729-100760229_R',
#  'lincRNA:chr6:100735579-100742779_R',
#  'lincRNA:chr5:95651544-95671794_R',
#  'lincRNA:chr5:95351569-95628894_R',
#  'lincRNA:chr5:95351569-95628894_F',
#  'lincRNA:chr5:94794194-94799319_R',
#  'lincRNA:chr5:94005444-94012744_R',
#  'lincRNA:chr5:93988844-94003469_R',
#  'lincRNA:chr5:93440069-93451144_F',
#  'lincRNA:chr5:92907201-92907645_R',
#  'lincRNA:chr5:92879196-92899168_F',
#  'lincRNA:chr5:92864719-92917133_F',
#  'lincRNA:chr5:92850844-92856719_R',
#  'lincRNA:chr5:92825244-92835469_R',
#  'lincRNA:chr5:92825244-92835469_F',
#  'lincRNA:chr5:92804819-92816519_R',
#  'lincRNA:chr5:92768070-92899138_R',
#  'lincRNA:chr5:92746841-92890702_R',
#  'lincRNA:chr5:92745794-92751919_F',
#  'lincRNA:chr5:88390860-88394207_F',
#  'lincRNA:chr5:88237556-88240804_F',
#  'lincRNA:chr5:87580664-87583451_F',
#  'lincRNA:chr5:86405094-86425344_R',
#  'lincRNA:chr5:86405094-86425344_F',
#  'lincRNA:chr5:86263137-86433524_F',
#  'lincRNA:chr5:86109465-86540020_F',
#  'lincRNA:chr5:82343269-82348544_F',
#  'lincRNA:chr5:81707769-81713444_R',
#  'lincRNA:chr5:81707769-81713444_F',
#  'lincRNA:chr5:81654602-81833836_R',
#  'lincRNA:chr5:81650244-81658219_R',
#  'lincRNA:chr5:80172719-80178619_F',
#  'lincRNA:chr5:77290085-77290467_F',
#  'lincRNA:chr5:77285769-77295769_R',
#  'lincRNA:chr5:77285769-77295769_F',
#  'lincRNA:chr5:757425-764373_R',
#  'lincRNA:chr5:757425-764373_F',
#  'lincRNA:chr5:74919144-74925819_R',
#  'lincRNA:chr5:74327969-74348269_F',
#  'lincRNA:chr5:73618674-73624122_R',
#  'lincRNA:chr5:72707719-72723794_R',
#  'lincRNA:chr5:71870020-71876804_F',
#  'lincRNA:chr5:71852903-71867570_R',
#  'lincRNA:chr5:71679069-71688944_R',
#  'lincRNA:chr5:71663069-71674169_F',
#  'lincRNA:chr5:6933782-7190925_F',
#  'lincRNA:chr5:67675269-67719019_R',
#  'lincRNA:chr5:67603294-67617869_R',
#  'lincRNA:chr5:67603294-67617869_F',
#  'lincRNA:chr5:67096567-67185924_R',
#  'lincRNA:chr5:67086094-67113044_R',
#  'lincRNA:chr5:66995256-67198428_R',
#  'lincRNA:chr5:66564951-67093417_R',
#  'lincRNA:chr5:65509705-65510491_F',
#  'lincRNA:chr5:60784193-60801393_R',
#  'lincRNA:chr5:60750818-60782018_R',
#  'lincRNA:chr5:60719293-60801393_R',
#  'lincRNA:chr5:60630018-60678968_R',
#  'lincRNA:chr5:60630018-60669918_F',
#  'lincRNA:chr5:60464943-60477543_R',
#  'lincRNA:chr5:58234093-58248293_R',
#  'lincRNA:chr5:57837393-57854070_R',
#  'lincRNA:chr5:54162493-54208143_R',
#  'lincRNA:chr5:54162493-54208143_F',
#  'lincRNA:chr5:54162397-54162890_R',
#  'lincRNA:chr5:54021218-54033693_R',
#  'lincRNA:chr5:54021218-54033693_F',
#  'lincRNA:chr5:53858193-53968993_F',
#  'lincRNA:chr5:53656393-53720118_F',
#  'lincRNA:chr5:5357650-5384825_F',
#  'lincRNA:chr5:52531518-52727218_R',
#  'lincRNA:chr5:44826668-44836868_F',
#  'lincRNA:chr5:44826637-44828692_F',
#  'lincRNA:chr5:44816593-44823034_F',
#  'lincRNA:chr5:43068217-43099440_R',
#  'lincRNA:chr5:43014835-43017310_F',
#  'lincRNA:chr5:42985502-42991184_F',
#  'lincRNA:chr5:42985499-42991206_F',
#  'lincRNA:chr5:42982464-42991322_F',
#  'lincRNA:chr5:38823068-38844393_F',
#  'lincRNA:chr5:38819481-38823547_R',
#  'lincRNA:chr5:38812198-38814135_R',
#  'lincRNA:chr5:38025798-38184036_R',
#  'lincRNA:chr5:37872452-37874996_R',
#  'lincRNA:chr5:3612325-3623500_F',
#  'lincRNA:chr5:34044618-34053161_F',
#  'lincRNA:chr5:32997143-33271418_F',
#  'lincRNA:chr5:32615943-32628968_R',
#  'lincRNA:chr5:32615943-32628968_F',
#  'lincRNA:chr5:32531468-32548668_R',
#  'lincRNA:chr5:27727218-28046018_R',
#  'lincRNA:chr5:27476174-27485293_R',
#  'lincRNA:chr5:25385943-25445890_R',
#  'lincRNA:chr5:18484318-18746268_R',
#  'lincRNA:chr5:18484318-18746268_F',
#  'lincRNA:chr5:179091169-179097344_R',
#  'lincRNA:chr5:178312369-178319594_R',
#  'lincRNA:chr5:178252169-178257549_R',
#  'lincRNA:chr5:178252169-178257549_F',
#  'lincRNA:chr5:176744094-176753119_R',
#  'lincRNA:chr5:176744094-176753119_F',
#  'lincRNA:chr5:173137442-173146695_R',
#  'lincRNA:chr5:173084644-173297044_R',
#  'lincRNA:chr5:173084644-173297044_F',
#  'lincRNA:chr5:172720869-172729944_F',
#  'lincRNA:chr5:172139570-172159241_R',
#  'lincRNA:chr5:171991045-172003620_R',
#  'lincRNA:chr5:171237095-171263795_R',
#  'lincRNA:chr5:1701400-1723250_R',
#  'lincRNA:chr5:1701400-1723250_F',
#  'lincRNA:chr5:159303797-159311222_F',
#  'lincRNA:chr5:159203779-159298391_R',
#  'lincRNA:chr5:157747709-157836781_R',
#  'lincRNA:chr5:1544500-1567142_R',
#  'lincRNA:chr5:1544500-1567142_F',
#  'lincRNA:chr5:153808732-153823632_R',
#  'lincRNA:chr5:153808732-153823632_F',
#  'lincRNA:chr5:151189307-151195107_R',
#  'lincRNA:chr5:150974507-150981382_F',
#  'lincRNA:chr5:150325388-150326043_F',
#  'lincRNA:chr5:150324533-150326042_R',
#  'lincRNA:chr5:150321437-150322233_R',
#  'lincRNA:chr5:150309462-150309673_R',
#  'lincRNA:chr5:150309462-150309673_F',
#  'lincRNA:chr5:149980882-149995557_R',
#  'lincRNA:chr5:149980882-149995557_F',
#  'lincRNA:chr5:149866432-149882132_R',
#  'lincRNA:chr5:148229632-148269232_R',
#  'lincRNA:chr5:147750932-147760207_R',
#  'lincRNA:chr5:147385957-147400457_F',
#  'lincRNA:chr5:147329082-147362557_F',
#  'lincRNA:chr5:146852660-146889494_R',
#  'lincRNA:chr5:146852194-146889094_R',
#  'lincRNA:chr5:144813732-145123982_R',
#  'lincRNA:chr5:141839041-141871766_R',
#  'lincRNA:chr5:141732516-141745491_F',
#  'lincRNA:chr5:141667191-141677391_R',
#  'lincRNA:chr5:139010791-139025266_F',
#  'lincRNA:chr5:135519476-135525376_R',
#  'lincRNA:chr5:134465126-134592001_R',
#  'lincRNA:chr5:134465126-134478076_R',
#  'lincRNA:chr5:134298401-134303601_R',
#  'lincRNA:chr5:134298401-134303601_F',
#  'lincRNA:chr5:133837051-133848098_R',
#  'lincRNA:chr5:133837051-133848098_F',
#  'lincRNA:chr5:131806278-131808704_F',
#  'lincRNA:chr5:131804581-131808735_F',
#  'lincRNA:chr5:131798076-131809576_R',
#  'lincRNA:chr5:131798076-131809576_F',
#  'lincRNA:chr5:131798076-131807951_R',
#  'lincRNA:chr5:131694766-131695812_F',
#  'lincRNA:chr5:127407926-127417781_F',
#  'lincRNA:chr5:127407926-127417751_F',
#  'lincRNA:chr5:127395508-127395983_R',
#  'lincRNA:chr5:127385751-127406047_R',
#  'lincRNA:chr5:127385751-127405576_F',
#  'lincRNA:chr5:127350725-127351188_R',
#  'lincRNA:chr5:127338220-127359852_F',
#  'lincRNA:chr5:127338040-127339371_R',
#  'lincRNA:chr5:127292876-127379626_R',
#  'lincRNA:chr5:126397151-126411151_R',
#  'lincRNA:chr5:126397151-126411151_F',
#  'lincRNA:chr5:126371352-126373205_R',
#  'lincRNA:chr5:126370776-126381926_R',
#  'lincRNA:chr5:126370776-126381926_F',
#  'lincRNA:chr5:12625075-12747025_R',
#  'lincRNA:chr5:126187125-126189758_F',
#  'lincRNA:chr5:124817426-124830024_R',
#  'lincRNA:chr5:124738151-124748189_F',
#  'lincRNA:chr5:124372523-124661140_F',
#  'lincRNA:chr5:123961601-123972101_F',
#  'lincRNA:chr5:121389576-121396926_R',
#  'lincRNA:chr5:120607301-120671176_R',
#  'lincRNA:chr5:119438251-119772601_F',
#  'lincRNA:chr5:1173255-1175321_F',
#  'lincRNA:chr5:1167850-1186275_R',
#  'lincRNA:chr5:115649076-115664086_F',
#  'lincRNA:chr5:115631476-115644551_R',
#  'lincRNA:chr5:115631476-115644551_F',
#  'lincRNA:chr5:114534926-114542826_R',
#  'lincRNA:chr5:1130775-1186275_R',
#  'lincRNA:chr5:111791901-111904001_F',
#  'lincRNA:chr5:108527309-108533551_R',
#  'lincRNA:chr5:108527309-108533551_F',
#  'lincRNA:chr5:106600-129725_F',
#  'lincRNA:chr5:102183195-102185259_F',
#  'lincRNA:chr5:10217425-10223699_R',
#  'lincRNA:chr5:10217425-10223699_F',
#  'lincRNA:chr5:102091626-102193726_F',
#  'lincRNA:chr4:53577368-53616143_F',
#  'lincRNA:chr4:47840518-47846712_R',
#  'lincRNA:chr4:4545549-4583049_F',
#  'lincRNA:chr4:42095918-42105968_R',
#  'lincRNA:chr4:40157905-40166455_F',
#  'lincRNA:chr4:38499655-38638805_F',
#  'lincRNA:chr4:38197205-38433455_R',
#  'lincRNA:chr4:38197205-38433455_F',
#  'lincRNA:chr4:3676927-3688227_R',
#  'lincRNA:chr4:3676927-3688227_F',
#  'lincRNA:chr4:3650727-3666752_R',
#  'lincRNA:chr4:36008565-36017494_R',
#  'lincRNA:chr4:3572927-3634877_R',
#  'lincRNA:chr4:3572927-3634877_F',
#  'lincRNA:chr4:3297502-3310352_F',
#  'lincRNA:chr4:295700-311175_F',
#  'lincRNA:chr4:28383262-28404481_R',
#  'lincRNA:chr4:2787377-2817302_R',
#  'lincRNA:chr4:26806777-26850102_R',
#  'lincRNA:chr4:26806777-26850102_F',
#  'lincRNA:chr4:26784325-26784977_R',
#  'lincRNA:chr4:2558327-2611352_F',
#  'lincRNA:chr4:2556227-2614827_F',
#  'lincRNA:chr4:2537401-2597920_F',
#  'lincRNA:chr4:25163077-25179402_R',
#  'lincRNA:chr4:25163077-25179402_F',
#  'lincRNA:chr4:24814752-24827052_F',
#  'lincRNA:chr4:2463252-2468502_R',
#  'lincRNA:chr4:24517527-24528051_R',
#  'lincRNA:chr4:24517527-24528002_R',
#  'lincRNA:chr4:245050-260725_R',
#  'lincRNA:chr4:23771777-23778877_R',
#  'lincRNA:chr4:23771777-23778877_F',
#  'lincRNA:chr4:17027927-17036327_F',
#  'lincRNA:chr4:16974897-17075526_R',
#  'lincRNA:chr4:16261632-16262082_R',
#  'lincRNA:chr4:16260982-16262107_F',
#  'lincRNA:chr4:16257882-16259621_R',
#  'lincRNA:chr4:16239177-16275952_R',
#  'lincRNA:chr4:15686521-15688229_R',
#  'lincRNA:chr4:15683426-15688771_R',
#  'lincRNA:chr4:15670034-15683205_F',
#  'lincRNA:chr4:15657202-15695627_R',
#  'lincRNA:chr4:15135577-15211177_F',
#  'lincRNA:chr4:129236000-129261500_F',
#  'lincRNA:chr4:129215150-129232550_F',
#  'lincRNA:chr4:129141800-129151475_F',
#  'lincRNA:chr4:128758375-128769050_R',
#  'lincRNA:chr4:128758375-128769050_F',
#  'lincRNA:chr4:127694975-127709825_R',
#  'lincRNA:chr4:127694975-127709825_F',
#  'lincRNA:chr4:127483782-127876561_R',
#  'lincRNA:chr4:125539675-125571625_F',
#  'lincRNA:chr4:125511350-125532750_R',
#  'lincRNA:chr4:125330825-125382425_F',
#  'lincRNA:chr4:124974717-125260135_F',
#  'lincRNA:chr4:124815913-124851577_F',
#  'lincRNA:chr4:123620575-123629031_R',
#  'lincRNA:chr4:120989952-120996677_R',
#  'lincRNA:chr4:120392402-120404152_R',
#  'lincRNA:chr4:11775222-11804038_R',
#  'lincRNA:chr4:11772073-11791490_R',
#  'lincRNA:chr4:11724168-11726750_R',
#  'lincRNA:chr4:11627337-11815582_R',
#  'lincRNA:chr4:115399526-115413226_R',
#  'lincRNA:chr4:113709183-113709999_F',
#  ...]

# %%
len(final_selected)
# Out:
# 16375

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='entropy', random_state=0)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[30  8]
#  [ 8 41]]
# accuracy: 0.8160919540229885
# precision: 0.8367346938775511
# recall: 0.8367346938775511
# f1-score: 0.8367346938775511
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        38
#            1       0.84      0.84      0.84        49
#
#     accuracy                           0.82        87
#    macro avg       0.81      0.81      0.81        87
# weighted avg       0.82      0.82      0.82        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Decision Tree\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Decision Tree')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[33  5]
#  [ 7 42]]
# accuracy: 0.8620689655172413
# precision: 0.8936170212765957
# recall: 0.8571428571428571
# f1-score: 0.875
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85        38
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.86        87
#    macro avg       0.86      0.86      0.86        87
# weighted avg       0.86      0.86      0.86        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Naive Bayes\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Naive Bayes')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC, LinearSVC
# classifier = LinearSVC()
classifier = SVC(kernel='linear')
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[36  2]
#  [ 5 44]]
# accuracy: 0.9195402298850575
# precision: 0.9565217391304348
# recall: 0.8979591836734694
# f1-score: 0.9263157894736843
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91        38
#            1       0.96      0.90      0.93        49
#
#     accuracy                           0.92        87
#    macro avg       0.92      0.92      0.92        87
# weighted avg       0.92      0.92      0.92        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - SVM\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - SVM')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200, criterion='gini', random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10, 40, 100],
    'max_features': [2, 'sqrt'],
    'min_samples_leaf': [1, 3, 6, 14],
    'min_samples_split': [2, 6, 14],
    'n_estimators': [100]
}
grid = GridSearchCV(RandomForestClassifier(), param_grid, verbose=3)
grid.fit(X_train, y_train)
print(grid.best_params_)
print(grid.best_estimator_)
y_pred = grid.predict(X_test)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.756 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf
total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.878 total time=   0.7s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.878 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.825 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.850 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.902 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.854 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.825 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.825 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.829 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.878 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.825 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.7s
# ...
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.780 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.829 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.780 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.800 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.780 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.775 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.750 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth
5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.825 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.800 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.829 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.829 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.800 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.854 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.805 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.800 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.850 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.800 total time=   0.6s
# {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 100}
# RandomForestClassifier(max_depth=10, max_features='sqrt', min_samples_leaf=3,
#                        min_samples_split=6)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[36  2]
#  [ 6 43]]
# accuracy: 0.9080459770114943
# precision: 0.9555555555555556
# recall: 0.8775510204081632
# f1-score: 0.9148936170212767
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90        38
#            1       0.96      0.88      0.91        49
#
#     accuracy                           0.91        87
#    macro avg       0.91      0.91      0.91        87
# weighted avg       0.91      0.91      0.91        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Random Forest\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Random Forest')
plt.legend(loc=4)
plt.show()
