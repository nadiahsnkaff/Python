# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiahsnkaff/Python/blob/main/SVD_Lasso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to handle datasets
import pandas as pd
import numpy as np

# to divide train and test set
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import StandardScaler, FunctionTransformer

# create pipeline
from sklearn.pipeline import Pipeline

# Singular Value Decomposition
from sklearn.decomposition import TruncatedSVD

# Lasso
from sklearn.linear_model import LassoCV

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load dataset
df=pd.read_csv('/content/drive/MyDrive/PythonProject/Breast_GSE70947.csv')
df.head()
# Out:
#    type  NM_144987  NM_013290  ENST00000322831  NM_001625  \
# 0     0   8.693318   7.718016         6.044438  10.747077
# 1     0   9.375980   7.072232         6.976741  10.429671
# 2     0   8.943442   7.964573         6.269055  10.825025
# 3     0   9.020798   7.824639         6.165165  11.646788
# 4     0   8.806154   7.555348         6.230969  11.635247
#
#    lincRNA:chr7:226042-232442_R  NM_032391  ENST00000238571  XR_108906  \
# 0                      9.133777   4.735581         5.634732   4.670231
# 1                      9.526500   5.221089         5.425187   4.860931
# 2                      9.396855   5.258506         5.824921   4.964604
# 3                      8.776462   4.648655         6.676692   4.770186
# 4                      8.911383   4.518054         6.520691   4.540453
#
#    NM_005937  ...  NM_207327  NM_001004477  NM_020700  NM_005895  NM_000679  \
# 0  11.152649  ...  10.453202      4.376090   5.597596  11.860087  11.321528
# 1  10.839289  ...  10.066372      4.383785   5.404546  11.636828   8.283747
# 2  10.884157  ...  10.380676      4.428892   5.356374  12.031338   9.420630
# 3  10.646459  ...  10.509871      4.381542   5.757179  11.944607  10.311339
# 4  10.939783  ...  10.552841      4.386116   6.851058  11.976510  10.904219
#
#    NR_003529  NR_036446  NM_001001957  lincRNA:chr7:29652000-29661000_R  \
# 0   4.486530   5.489959      5.810069                          4.834056
# 1   4.770318   5.345571      4.457930                          4.441395
# 2   4.394069   5.851030      4.508072                          4.568262
# 3   4.451118   6.117379      4.505663                          4.413361
# 4   4.432566   6.286439      4.540453                          4.412933
#
#    ENST00000494108
# 0         4.383929
# 1         4.411587
# 2         4.316081
# 3         4.537626
# 4         4.452250
#
# [5 rows x 16383 columns]

# %%
df.shape
# Out:
# (289, 16383)

# %%
target_name = 'type'

#separate object for target feature
y = df[target_name]

#separate object for input feature
X = df.drop(target_name, axis=1)

# %%
#split the dataset into training set and test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    # we are setting the seed here
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((202, 16382), (87, 16382))

# %%
X_test.shape, y_test.shape
# Out:
# ((87, 16382), (87,))

# %%
# feature scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### SVD

# %%
scaler_1 = StandardScaler()
X_scld = scaler_1.fit_transform(X)

# %%
features_size = len(X.columns)

# %%
features_size
# Out:
# 16382

# %%
svd1=TruncatedSVD(n_components=16381, algorithm='randomized')

train_svd1_fitting = svd1.fit(X_scld, y)

# %%
svd1.singular_values_.shape
# Out:
# (289,)

# %%
svd1.components_.shape
# Out:
# (289, 16382)

# %%
n_pcs= svd1.components_.shape[0]
n_pcs
# Out:
# 289

# %%
n_pcs= svd1.components_.shape[0]

# get the index of the most important feature on EACH component i.e. largest absolute value
# using LIST COMPREHENSION HERE

most_important = [np.abs(svd1.components_[i]).argmax() for i in range(n_pcs)]

initial_feature_names = X.columns

# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

# using LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i+1): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df_SVD = pd.DataFrame(sorted(dic.items()))
df_SVD.columns=['Components','Important Feature']

# %%
df_SVD.shape
# Out:
# (289, 2)

# %%
df_SVD
# Out:
#     Components                   Important Feature
# 0          PC1                           NM_152722
# 1         PC10                           NM_017439
# 2        PC100  lincRNA:chr1:237076752-237090527_F
# 3        PC101                     ENST00000427181
# 4        PC102                       A_33_P3358653
# ..         ...                                 ...
# 284       PC95                     ENST00000456585
# 285       PC96  lincRNA:chr8:128976068-129037346_R
# 286       PC97  lincRNA:chr2:218130330-218481005_F
# 287       PC98                        NM_001004450
# 288       PC99                     ENST00000407838
#
# [289 rows x 2 columns]

# %%
selected_features_by_SVD = df_SVD['Important Feature'].values

# %%
len(selected_features_by_SVD)
# Out:
# 289

# %% [markdown]
# ### LASSO

# %%
scaler_1 = StandardScaler()
X_scld = scaler_1.fit_transform(X)

# %%
#Lasso
from sklearn.linear_model import LassoCV

# %%
lcv = LassoCV(n_jobs=-1, verbose=1)

# %%
lcv.fit(X_scld, y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.4min finished
# LassoCV(n_jobs=-1, verbose=1)

# %%
print(lcv.alpha_)
# Out:
# 0.0164307283370793

# %%
lcv.score(X_test, y_test)
# Out:
# 0.9173728725903179

# %%
lcv_mask = lcv.coef_!=0

# %%
print(lcv_mask)
# Out:
# [False False False ... False False False]

# %%
reduced_X = X.loc[:, lcv_mask]

# %%
reduced_X.columns
# Out:
# Index(['ERCC-00071_128', 'lincRNA:chr12:59990908-60003558_R', 'NR_024062',
#        'NM_014966', 'NM_003886', 'NM_001007471', 'NM_001100917',
#        'lincRNA:chr11:117668490-117680359_R', 'ENST00000557073', 'NM_004426',
#        ...
#        'NM_153708', 'NM_001113523', 'NM_001083926',
#        'lincRNA:chr6:138145796-138182040_R', 'NM_152725', 'NM_001142285',
#        'ENST00000368582', 'THC2537731', 'NM_006653', 'NR_036446'],
#       dtype='object', length=143)

# %%
selected_features_lasso = reduced_X.columns

# %%
len(selected_features_lasso)
# Out:
# 143

# %% [markdown]
# ### FINAL Result

# %%
features=sorted(df.drop('type',axis=1).columns)

# %%
df.head()
# Out:
#    type  NM_144987  NM_013290  ENST00000322831  NM_001625  \
# 0     0   8.693318   7.718016         6.044438  10.747077
# 1     0   9.375980   7.072232         6.976741  10.429671
# 2     0   8.943442   7.964573         6.269055  10.825025
# 3     0   9.020798   7.824639         6.165165  11.646788
# 4     0   8.806154   7.555348         6.230969  11.635247
#
#    lincRNA:chr7:226042-232442_R  NM_032391  ENST00000238571  XR_108906  \
# 0                      9.133777   4.735581         5.634732   4.670231
# 1                      9.526500   5.221089         5.425187   4.860931
# 2                      9.396855   5.258506         5.824921   4.964604
# 3                      8.776462   4.648655         6.676692   4.770186
# 4                      8.911383   4.518054         6.520691   4.540453
#
#    NM_005937  ...  NM_207327  NM_001004477  NM_020700  NM_005895  NM_000679  \
# 0  11.152649  ...  10.453202      4.376090   5.597596  11.860087  11.321528
# 1  10.839289  ...  10.066372      4.383785   5.404546  11.636828   8.283747
# 2  10.884157  ...  10.380676      4.428892   5.356374  12.031338   9.420630
# 3  10.646459  ...  10.509871      4.381542   5.757179  11.944607  10.311339
# 4  10.939783  ...  10.552841      4.386116   6.851058  11.976510  10.904219
#
#    NR_003529  NR_036446  NM_001001957  lincRNA:chr7:29652000-29661000_R  \
# 0   4.486530   5.489959      5.810069                          4.834056
# 1   4.770318   5.345571      4.457930                          4.441395
# 2   4.394069   5.851030      4.508072                          4.568262
# 3   4.451118   6.117379      4.505663                          4.413361
# 4   4.432566   6.286439      4.540453                          4.412933
#
#    ENST00000494108
# 0         4.383929
# 1         4.411587
# 2         4.316081
# 3         4.537626
# 4         4.452250
#
# [5 rows x 16383 columns]

# %%
# Putting all selections together
def get_true_false(selected_features, features):
    selected_t_f = []
    for feature in features:
        if feature in selected_features:
            selected_t_f.append(True)
        else:
            selected_t_f.append(False)
    return selected_t_f

# %%
features = sorted(df.drop('type', axis=1).columns)
df_selections = pd.DataFrame({'Feature': features,
                              'SVD': get_true_false(selected_features_by_SVD, features),
                              'Lasso': get_true_false(selected_features_lasso, features)})
df_selections['Total'] = df_selections['SVD'].astype(int) + df_selections['Lasso'].astype(int)
df_selections = df_selections.sort_values(['Total', 'Feature'], ascending=False)
df_selections.index = range(1, len(df_selections) + 1)

# %%
df_selections[:10]
# Out:
#                                Feature    SVD  Lasso  Total
# 1   lincRNA:chr6:138145796-138182040_R   True   True      2
# 2                            NR_036444   True   True      2
# 3                         NM_001145059   True   True      2
# 4                         NM_001080482   True   True      2
# 5                      ENST00000427181   True   True      2
# 6     lincRNA:chrX:73164675-73232875_R   True  False      1
# 7     lincRNA:chrX:68110750-68116075_R   True  False      1
# 8   lincRNA:chrX:138994509-138999734_F  False   True      1
# 9   lincRNA:chr9:132104121-132121810_R   True  False      1
# 10      lincRNA:chr8:6516692-6533242_R   True  False      1

# %%
final_selected = list(df_selections[df_selections['Total'] > 1]['Feature'])

# %%
final_selected
# Out:
# ['lincRNA:chr6:138145796-138182040_R',
#  'NR_036444',
#  'NM_001145059',
#  'NM_001080482',
#  'ENST00000427181']

# %%
len(final_selected)
# Out:
# 5

# %%
df = df[final_selected]
X = df.values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='entropy', random_state=0)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[29 15]
#  [26 17]]
# accuracy: 0.5287356321839081
# precision: 0.53125
# recall: 0.3953488372093023
# f1-score: 0.4533333333333333
#               precision    recall  f1-score   support
#
#            0       0.53      0.66      0.59        44
#            1       0.53      0.40      0.45        43
#
#     accuracy                           0.53        87
#    macro avg       0.53      0.53      0.52        87
# weighted avg       0.53      0.53      0.52        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Decision Tree\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Normal','Cancer'])
ax.yaxis.set_ticklabels(['Normal','Cancer'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Decision Tree')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[42  2]
#  [35  8]]
# accuracy: 0.5747126436781609
# precision: 0.8
# recall: 0.18604651162790697
# f1-score: 0.3018867924528302
#               precision    recall  f1-score   support
#
#            0       0.55      0.95      0.69        44
#            1       0.80      0.19      0.30        43
#
#     accuracy                           0.57        87
#    macro avg       0.67      0.57      0.50        87
# weighted avg       0.67      0.57      0.50        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Naive Bayes\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Normal','Cancer'])
ax.yaxis.set_ticklabels(['Normal','Cancer'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Naive Bayes')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC, LinearSVC
# classifier = LinearSVC()
classifier = SVC(kernel='linear')
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[32 12]
#  [21 22]]
# accuracy: 0.6206896551724138
# precision: 0.6470588235294118
# recall: 0.5116279069767442
# f1-score: 0.5714285714285714
#               precision    recall  f1-score   support
#
#            0       0.60      0.73      0.66        44
#            1       0.65      0.51      0.57        43
#
#     accuracy                           0.62        87
#    macro avg       0.63      0.62      0.62        87
# weighted avg       0.63      0.62      0.62        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - SVM\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Normal','Cancer'])
ax.yaxis.set_ticklabels(['Normal','Cancer'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - SVM')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200, criterion='gini', random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10, 40, 100],
    'max_features': [2, 'sqrt'],
    'min_samples_leaf': [1, 3, 6, 14],
    'min_samples_split': [2, 6, 14],
    'n_estimators': [100]
}
grid = GridSearchCV(RandomForestClassifier(), param_grid, verbose=3)
grid.fit(X_train, y_train)
print(grid.best_params_)
print(grid.best_estimator_)
y_pred = grid.predict(X_test)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.561 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.525 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.725 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.525 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.561 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.634 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.450 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.675 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.550 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.585 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.585 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.525 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf
total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.561 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.537 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.634 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.500 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.610 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.610 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.525 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.650 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.561 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.683 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.475 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.650 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.575 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.610 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.550 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.650 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.575 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.585 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.683 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.700 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.650 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.650 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.585 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.634 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.625 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.675 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.625 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.634 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.634 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.550 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.650 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.675 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.561 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.575 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.650 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.450 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.675 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.550 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.561 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.610 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.550 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.610 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.659 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.575 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.675 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.575 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.561 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.650 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.550 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.659 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.550 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.650 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.575 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.683 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.700 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.600 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.537 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.707 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.550 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.700 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.537 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.634 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.575 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.700 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.550 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.610 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.683 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.675 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.625 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.585 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.634 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.550 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.700 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.650 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.610 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.707 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.550 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.675 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.625 total time=   0.3s
# {'criterion': 'gini', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_leaf': 14, 'min_samples_split': 2, 'n_estimators': 100}
# RandomForestClassifier(max_depth=100, min_samples_leaf=14)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[28 16]
#  [20 23]]
# accuracy: 0.5862068965517241
# precision: 0.5897435897435898
# recall: 0.5348837209302325
# f1-score: 0.5609756097560976
#               precision    recall  f1-score   support
#
#            0       0.58      0.64      0.61        44
#            1       0.59      0.53      0.56        43
#
#     accuracy                           0.59        87
#    macro avg       0.59      0.59      0.58        87
# weighted avg       0.59      0.59      0.59        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Random Forest\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Normal','Cancer'])
ax.yaxis.set_ticklabels(['Normal','Cancer'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Random Forest')
plt.legend(loc=4)
plt.show()
