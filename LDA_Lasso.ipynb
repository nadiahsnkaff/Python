# %% [markdown]
# <a href="https://colab.research.google.com/github/nadiahsnkaff/Python/blob/main/LDA_Lasso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to handle datasets
import pandas as pd
import numpy as np

# to divide train and test set
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import StandardScaler, FunctionTransformer

# create pipeline
from sklearn.pipeline import Pipeline

# LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# Lasso
from sklearn.linear_model import LassoCV

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load dataset
df=pd.read_csv('/content/drive/MyDrive/PythonProject/Breast_GSE70947.csv')
df.head()
# Out:
#    type  NM_144987  NM_013290  ENST00000322831  NM_001625  \
# 0     0   8.693318   7.718016         6.044438  10.747077
# 1     0   9.375980   7.072232         6.976741  10.429671
# 2     0   8.943442   7.964573         6.269055  10.825025
# 3     0   9.020798   7.824639         6.165165  11.646788
# 4     0   8.806154   7.555348         6.230969  11.635247
#
#    lincRNA:chr7:226042-232442_R  NM_032391  ENST00000238571  XR_108906  \
# 0                      9.133777   4.735581         5.634732   4.670231
# 1                      9.526500   5.221089         5.425187   4.860931
# 2                      9.396855   5.258506         5.824921   4.964604
# 3                      8.776462   4.648655         6.676692   4.770186
# 4                      8.911383   4.518054         6.520691   4.540453
#
#    NM_005937  ...  NM_207327  NM_001004477  NM_020700  NM_005895  NM_000679  \
# 0  11.152649  ...  10.453202      4.376090   5.597596  11.860087  11.321528
# 1  10.839289  ...  10.066372      4.383785   5.404546  11.636828   8.283747
# 2  10.884157  ...  10.380676      4.428892   5.356374  12.031338   9.420630
# 3  10.646459  ...  10.509871      4.381542   5.757179  11.944607  10.311339
# 4  10.939783  ...  10.552841      4.386116   6.851058  11.976510  10.904219
#
#    NR_003529  NR_036446  NM_001001957  lincRNA:chr7:29652000-29661000_R  \
# 0   4.486530   5.489959      5.810069                          4.834056
# 1   4.770318   5.345571      4.457930                          4.441395
# 2   4.394069   5.851030      4.508072                          4.568262
# 3   4.451118   6.117379      4.505663                          4.413361
# 4   4.432566   6.286439      4.540453                          4.412933
#
#    ENST00000494108
# 0         4.383929
# 1         4.411587
# 2         4.316081
# 3         4.537626
# 4         4.452250
#
# [5 rows x 16383 columns]

# %%
df.shape
# Out:
# (289, 16383)

# %%
target_name = 'type'

#separate object for target feature
y = df[target_name]

#separate object for input feature
X = df.drop(target_name, axis=1)

# %%
#split the dataset into training set and test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,
                                                    # we are setting the seed here
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((202, 16382), (87, 16382))

# %%
X_test.shape, y_test.shape
# Out:
# ((87, 16382), (87,))

# %%
# feature scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### LDA

# %%
scaler_1 = StandardScaler()
X_scld = scaler_1.fit_transform(X)

# %%
lda1=LDA(store_covariance=True)

train_lda_fitting = lda1.fit(X_scld, y)

# %%
n_pcs= lda1.covariance_.shape[0]

# get the index of the most important feature on EACH component i.e. largest absolute value
# using LIST COMPREHENSION HERE
most_important = [np.abs(lda1.covariance_[i]).argmax() for i in range(n_pcs)]

initial_feature_names = X.columns

# get the names
most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]

# using LIST COMPREHENSION HERE AGAIN
dic = {'PC{}'.format(i+1): most_important_names[i] for i in range(n_pcs)}

# build the dataframe
df_LDA = pd.DataFrame(sorted(dic.items()))
df_LDA.columns=['Components','Important Feature']

# %%
df_LDA.shape
# Out:
# (16382, 2)

# %%
df_LDA
# Out:
#       Components                   Important Feature
# 0            PC1                           NM_144987
# 1           PC10                           NM_152493
# 2          PC100  lincRNA:chr9:132096359-132104173_R
# 3         PC1000                     ENST00000319813
# 4        PC10000                           NM_178568
# ...          ...                                 ...
# 16377     PC9995                        NM_001012409
# 16378     PC9996                           NM_001277
# 16379     PC9997  lincRNA:chr6:147227807-147238032_R
# 16380     PC9998                           NM_000517
# 16381     PC9999                           NM_000830
#
# [16382 rows x 2 columns]

# %%
selected_features_by_LDA = df_LDA['Important Feature'].values

# %%
len(selected_features_by_LDA)
# Out:
# 16382

# %% [markdown]
# ### LASSO

# %%
scaler_1 = StandardScaler()
X_scld = scaler_1.fit_transform(X)

# %%
#Lasso
from sklearn.linear_model import LassoCV

# %%
lcv = LassoCV(n_jobs=-1, verbose=1)

# %%
lcv.fit(X_scld, y)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  2.2min finished
# LassoCV(n_jobs=-1, verbose=1)

# %%
print(lcv.alpha_)
# Out:
# 0.0164307283370793

# %%
lcv.score(X_test, y_test)
# Out:
# 0.9173728725903179

# %%
lcv_mask = lcv.coef_!=0

# %%
print(lcv_mask)
# Out:
# [False False False ... False False False]

# %%
reduced_X = X.loc[:, lcv_mask]

# %%
reduced_X.columns
# Out:
# Index(['ERCC-00071_128', 'lincRNA:chr12:59990908-60003558_R', 'NR_024062',
#        'NM_014966', 'NM_003886', 'NM_001007471', 'NM_001100917',
#        'lincRNA:chr11:117668490-117680359_R', 'ENST00000557073', 'NM_004426',
#        ...
#        'NM_153708', 'NM_001113523', 'NM_001083926',
#        'lincRNA:chr6:138145796-138182040_R', 'NM_152725', 'NM_001142285',
#        'ENST00000368582', 'THC2537731', 'NM_006653', 'NR_036446'],
#       dtype='object', length=143)

# %%
selected_features_lasso = reduced_X.columns

# %%
len(selected_features_lasso)
# Out:
# 143

# %% [markdown]
# ### FINAL Result

# %%
features=sorted(df.drop('type',axis=1).columns)

# %%
df.head()
# Out:
#    type  NM_144987  NM_013290  ENST00000322831  NM_001625  \
# 0     0   8.693318   7.718016         6.044438  10.747077
# 1     0   9.375980   7.072232         6.976741  10.429671
# 2     0   8.943442   7.964573         6.269055  10.825025
# 3     0   9.020798   7.824639         6.165165  11.646788
# 4     0   8.806154   7.555348         6.230969  11.635247
#
#    lincRNA:chr7:226042-232442_R  NM_032391  ENST00000238571  XR_108906  \
# 0                      9.133777   4.735581         5.634732   4.670231
# 1                      9.526500   5.221089         5.425187   4.860931
# 2                      9.396855   5.258506         5.824921   4.964604
# 3                      8.776462   4.648655         6.676692   4.770186
# 4                      8.911383   4.518054         6.520691   4.540453
#
#    NM_005937  ...  NM_207327  NM_001004477  NM_020700  NM_005895  NM_000679  \
# 0  11.152649  ...  10.453202      4.376090   5.597596  11.860087  11.321528
# 1  10.839289  ...  10.066372      4.383785   5.404546  11.636828   8.283747
# 2  10.884157  ...  10.380676      4.428892   5.356374  12.031338   9.420630
# 3  10.646459  ...  10.509871      4.381542   5.757179  11.944607  10.311339
# 4  10.939783  ...  10.552841      4.386116   6.851058  11.976510  10.904219
#
#    NR_003529  NR_036446  NM_001001957  lincRNA:chr7:29652000-29661000_R  \
# 0   4.486530   5.489959      5.810069                          4.834056
# 1   4.770318   5.345571      4.457930                          4.441395
# 2   4.394069   5.851030      4.508072                          4.568262
# 3   4.451118   6.117379      4.505663                          4.413361
# 4   4.432566   6.286439      4.540453                          4.412933
#
#    ENST00000494108
# 0         4.383929
# 1         4.411587
# 2         4.316081
# 3         4.537626
# 4         4.452250
#
# [5 rows x 16383 columns]

# %%
# Putting all selections together
def get_true_false(selected_features, features):
    selected_t_f = []
    for feature in features:
        if feature in selected_features:
            selected_t_f.append(True)
        else:
            selected_t_f.append(False)
    return selected_t_f

# %%
features = sorted(df.drop('type', axis=1).columns)
df_selections = pd.DataFrame({'Feature': features,
                              'LDA': get_true_false(selected_features_by_LDA, features),
                              'Lasso': get_true_false(selected_features_lasso, features)})
df_selections['Total'] = df_selections['LDA'].astype(int) + df_selections['Lasso'].astype(int)
df_selections = df_selections.sort_values(['Total', 'Feature'], ascending=False)
df_selections.index = range(1, len(df_selections) + 1)

# %%
df_selections[:10]
# Out:
#                                Feature   LDA  Lasso  Total
# 1   lincRNA:chrX:138994509-138999734_F  True   True      2
# 2         lincRNA:chr8:590406-605477_F  True   True      2
# 3     lincRNA:chr8:58115146-58143017_F  True   True      2
# 4   lincRNA:chr7:129244514-129251414_F  True   True      2
# 5   lincRNA:chr6:138145796-138182040_R  True   True      2
# 6     lincRNA:chr5:66995256-67198428_R  True   True      2
# 7     lincRNA:chr5:27727218-28046018_R  True   True      2
# 8     lincRNA:chr2:64478803-64479989_R  True   True      2
# 9   lincRNA:chr2:134933146-134933909_R  True   True      2
# 10  lincRNA:chr2:102597068-102606493_R  True   True      2

# %%
final_selected = list(df_selections[df_selections['Total'] > 1]['Feature'])

# %%
final_selected
# Out:
# ['lincRNA:chrX:138994509-138999734_F',
#  'lincRNA:chr8:590406-605477_F',
#  'lincRNA:chr8:58115146-58143017_F',
#  'lincRNA:chr7:129244514-129251414_F',
#  'lincRNA:chr6:138145796-138182040_R',
#  'lincRNA:chr5:66995256-67198428_R',
#  'lincRNA:chr5:27727218-28046018_R',
#  'lincRNA:chr2:64478803-64479989_R',
#  'lincRNA:chr2:134933146-134933909_R',
#  'lincRNA:chr2:102597068-102606493_R',
#  'lincRNA:chr21:44895804-44899414_F',
#  'lincRNA:chr18:68016295-68023870_F',
#  'lincRNA:chr17:44271698-44279998_R',
#  'lincRNA:chr16:72557192-72698869_R',
#  'lincRNA:chr12:76652565-76706444_F',
#  'lincRNA:chr12:60375008-60734083_R',
#  'lincRNA:chr12:59990908-60003558_R',
#  'lincRNA:chr11:117668490-117680359_R',
#  'XR_132698',
#  'XR_110535',
#  'XR_109856',
#  'XR_108644',
#  'XM_003119820',
#  'XM_002343033',
#  'THC2736258',
#  'THC2603827',
#  'THC2537731',
#  'NR_038428',
#  'NR_036446',
#  'NR_036444',
#  'NR_033987',
#  'NR_028330',
#  'NR_026835',
#  'NR_026681',
#  'NR_026556',
#  'NR_024421',
#  'NR_024062',
#  'NR_002163',
#  'NM_172370',
#  'NM_153708',
#  'NM_153426',
#  'NM_152779',
#  'NM_152725',
#  'NM_152657',
#  'NM_144625',
#  'NM_144620',
#  'NM_144606',
#  'NM_139056',
#  'NM_138764',
#  'NM_053017',
#  'NM_033204',
#  'NM_032138',
#  'NM_031491',
#  'NM_025009',
#  'NM_024660',
#  'NM_019076',
#  'NM_018242',
#  'NM_018106',
#  'NM_017938',
#  'NM_016442',
#  'NM_016277',
#  'NM_014966',
#  'NM_014632',
#  'NM_012125',
#  'NM_007225',
#  'NM_007174',
#  'NM_006653',
#  'NM_006494',
#  'NM_006480',
#  'NM_006292',
#  'NM_006288',
#  'NM_006145',
#  'NM_006101',
#  'NM_006049',
#  'NM_005623',
#  'NM_004791',
#  'NM_004770',
#  'NM_004426',
#  'NM_004064',
#  'NM_003950',
#  'NM_003886',
#  'NM_003480',
#  'NM_003301',
#  'NM_002960',
#  'NM_002435',
#  'NM_001785',
#  'NM_001742',
#  'NM_001511',
#  'NM_001361',
#  'NM_001195263',
#  'NM_001195187',
#  'NM_001174103',
#  'NM_001145059',
#  'NM_001142285',
#  'NM_001133',
#  'NM_001127395',
#  'NM_001113523',
#  'NM_001102562',
#  'NM_001100917',
#  'NM_001098635',
#  'NM_001086521',
#  'NM_001083926',
#  'NM_001080482',
#  'NM_001049',
#  'NM_001048212',
#  'NM_001042483',
#  'NM_001040655',
#  'NM_001007471',
#  'NM_001005199',
#  'NM_001004333',
#  'NM_000602',
#  'NM_000413',
#  'ERCC-00071_128',
#  'ENST00000557073',
#  'ENST00000497634',
#  'ENST00000477589',
#  'ENST00000468376',
#  'ENST00000466212',
#  'ENST00000449730',
#  'ENST00000427181',
#  'ENST00000397648',
#  'ENST00000394488',
#  'ENST00000379225',
#  'ENST00000370795',
#  'ENST00000369319',
#  'ENST00000368582',
#  'ENST00000244070',
#  'ENST00000238638',
#  'BC066898',
#  'BC030111',
#  'A_33_P3390678',
#  'A_33_P3374982',
#  'A_33_P3221888',
#  'A_33_P3210605',
#  'AY358259',
#  'AK131268',
#  'AK123930',
#  'AK097159',
#  'AK094155',
#  'AK057888',
#  'AK024141',
#  'AK023337']

# %%
len(final_selected)
# Out:
# 142

# %%
df = df[final_selected]
X = df.values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion='entropy', random_state=0)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[31  9]
#  [ 7 40]]
# accuracy: 0.8160919540229885
# precision: 0.8163265306122449
# recall: 0.851063829787234
# f1-score: 0.8333333333333334
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.79        40
#            1       0.82      0.85      0.83        47
#
#     accuracy                           0.82        87
#    macro avg       0.82      0.81      0.81        87
# weighted avg       0.82      0.82      0.82        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Decision Tree\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Normal','Cancer'])
ax.yaxis.set_ticklabels(['Normal','Cancer'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Decision Tree')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[35  5]
#  [ 0 47]]
# accuracy: 0.9425287356321839
# precision: 0.9038461538461539
# recall: 1.0
# f1-score: 0.9494949494949495
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93        40
#            1       0.90      1.00      0.95        47
#
#     accuracy                           0.94        87
#    macro avg       0.95      0.94      0.94        87
# weighted avg       0.95      0.94      0.94        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Naive Bayes\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Normal','Cancer'])
ax.yaxis.set_ticklabels(['Normal','Cancer'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Naive Bayes')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC, LinearSVC
# classifier = LinearSVC()
classifier = SVC(kernel='linear')
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[39  1]
#  [ 0 47]]
# accuracy: 0.9885057471264368
# precision: 0.9791666666666666
# recall: 1.0
# f1-score: 0.9894736842105263
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        40
#            1       0.98      1.00      0.99        47
#
#     accuracy                           0.99        87
#    macro avg       0.99      0.99      0.99        87
# weighted avg       0.99      0.99      0.99        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - SVM\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Normal','Cancer'])
ax.yaxis.set_ticklabels(['Normal','Cancer'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - SVM')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200, criterion='gini', random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [10, 40, 100],
    'max_features': [2, 'sqrt'],
    'min_samples_leaf': [1, 3, 6, 14],
    'min_samples_split': [2, 6, 14],
    'n_estimators': [100]
}
grid = GridSearchCV(RandomForestClassifier(), param_grid, verbose=3)
grid.fit(X_train, y_train)
print(grid.best_params_)
print(grid.best_estimator_)
y_pred = grid.predict(X_test)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.976 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.850 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.878 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.927 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.878 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.927 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.850 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.902 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.878 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.976 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.976 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.902 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.902 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=1.000 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.854 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.825 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.927 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=1.000 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.976 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# ...
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=1.000 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.976 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.976 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=2, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.902 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.878 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.950 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=3, min_samples_split=14, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.878 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=6, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.902 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.900 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=6, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.902 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.925 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=2, n_estimators=100;, score=0.900 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.951 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.927 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=6, n_estimators=100;, score=0.850 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.951 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.878 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.925 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=100, max_features=sqrt, min_samples_leaf=14, min_samples_split=14, n_estimators=100;, score=0.875 total time=   0.2s
# {'criterion': 'gini', 'max_depth': 40, 'max_features': 2, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 100}
# RandomForestClassifier(max_depth=40, max_features=2, min_samples_leaf=6,
#                        min_samples_split=6)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix

#Generate the confusion matrix
cf_matrix = confusion_matrix(y_test, y_pred)

print('confusion matrix:\n', cf_matrix)
print('accuracy:', metrics.accuracy_score(y_test, y_pred))
print('precision:', metrics.precision_score(y_test, y_pred))
print('recall:', metrics.recall_score(y_test, y_pred))
print('f1-score:', metrics.f1_score(y_test, y_pred))
print(metrics.classification_report(y_test, y_pred))
# Out:
# confusion matrix:
#  [[38  2]
#  [ 3 44]]
# accuracy: 0.9425287356321839
# precision: 0.9565217391304348
# recall: 0.9361702127659575
# f1-score: 0.946236559139785
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        40
#            1       0.96      0.94      0.95        47
#
#     accuracy                           0.94        87
#    macro avg       0.94      0.94      0.94        87
# weighted avg       0.94      0.94      0.94        87

# %%
import seaborn as sns

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
ax.set_title('Confusion Matrix - Random Forest\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['Normal','Cancer'])
ax.yaxis.set_ticklabels(['Normal','Cancer'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred)
auc = metrics.roc_auc_score(y_test, y_pred)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('AUC-ROC Curve - Random Forest')
plt.legend(loc=4)
plt.show()
